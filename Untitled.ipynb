# %%
import os
from google.colab import drive
drive.mount('/content/drive')

path = "/content/drive/My Drive"

os.chdir(path)
os.listdir(path)

# %%
# !nvidia-smi

# %%
# !pip install pyunpack
# !pip install patool
from pyunpack import Archive
Archive('/content/drive/My Drive/Colab/Notebooks/wavs.zip').extractall('/content/drive/My Drive/Colab/Notebooks/vits/wavs')

# %%
import os
from google.colab import drive
drive.mount('/content/drive')

path = "/content/drive/My Drive/Colab/Notebooks/vits/"

os.chdir(path)
os.listdir(path)

# %%
# !pip install -r requirements.txt
# !sudo apt-get install espeak -y

# %%
# !sudo apt-get install sox

# %%
# !pip install jieba

# %%
import os
from google.colab import drive
drive.mount('/content/drive')

path = "/content/drive/My Drive/Colab/Notebooks/vits/monotonic_align"

os.chdir(path)
os.listdir(path)

# %%
# !python setup.py build_ext --inplace

# %%
import os
from google.colab import drive
drive.mount('/content/drive')

path = "/content/drive/My Drive/Colab/Notebooks/vits/"

os.chdir(path)
os.listdir(path)

# %%
# !python preprocess.py --text_index 2 --filelists filelists/tricolor_train.txt filelists/tricolor_valid.txt filelists/tricolor_test.txt --text_cleaners chinese_cleaners2

# %%
# !python train_ms.py -c configs/tricolor_mul.json -m tricolor
# Out:
# [INFO] {'train': {'log_interval': 200, 'eval_interval': 1000, 'seed': 1234, 'epochs': 800, 'learning_rate': 0.0002, 'betas': [0.8, 0.99], 'eps': 1e-09, 'batch_size': 16, 'fp16_run': True, 'lr_decay': 0.999875, 'segment_size': 8192, 'init_lr_ratio': 1, 'warmup_epochs': 0, 'c_mel': 45, 'c_kl': 1.0}, 'data': {'training_files': 'filelists/tricolor_train.txt.cleaned', 'validation_files': 'filelists/tricolor_valid.txt.cleaned', 'text_cleaners': ['chinese_cleaners2'], 'max_wav_value': 32768.0, 'sampling_rate': 22050, 'filter_length': 1024, 'hop_length': 256, 'win_length': 1024, 'n_mel_channels': 80, 'mel_fmin': 0.0, 'mel_fmax': None, 'add_blank': True, 'n_speakers': 5, 'cleaned_text': True}, 'model': {'inter_channels': 192, 'hidden_channels': 192, 'filter_channels': 768, 'n_heads': 2, 'n_layers': 6, 'kernel_size': 3, 'p_dropout': 0.1, 'resblock': '1', 'resblock_kernel_sizes': [3, 7, 11], 'resblock_dilation_sizes': [[1, 3, 5], [1, 3, 5], [1, 3, 5]], 'upsample_rates': [8, 8, 2, 2], 'upsample_
# ...
